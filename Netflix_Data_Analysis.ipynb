# %% [markdown]
# <a href="https://colab.research.google.com/github/ShagunSharma98/Netflix---Data-Exploration-and-Visualization/blob/main/Netflix_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(pd.read_csv('/content/drive/MyDrive/netflix.csv'))
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# Find out the missing or NaN values in the dataset

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.isna())

# %% [markdown]
# As we can see, a lot of records in the data doesn't have values for **Director, Cast and Country** fields
#
#
# Since we are interested in increasing the revenue of Netflix, our main objective is to figure out which all shows and movies performed the best.
#
# We will firstly look at the distribution of how many tv shows and movies are present in netflix. Later on, we will specifically start analysing more details about the ones that fetched the best reviews

# %%
sns.countplot(x= 'type', data=data)

# %%
# plt.figure(figsize=(22,10))
data["listed_in"].value_counts()[:10].plot(kind="barh", color="red")
plt.title("Top 10 Genres of NETFLIX",size=20);

# %% [markdown]
# We have a lot of movies compared to TV shows, hence we will split our data so that our analysis is not skewed
#
# Before that, we need to clean/preprocess our data to get better insights

# %% [markdown]
# # Movies

# %%
df = data.copy()
df = df[df['type'] == 'Movie']

df.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# 0                                       United States  September 25, 2021
# 6                                                 NaN  September 24, 2021
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                       United States  September 24, 2021
# 12                            Germany, Czech Republic  September 23, 2021
#
#     release_year rating duration  \
# 0           2020  PG-13   90 min
# 6           2021     PG   91 min
# 7           1993  TV-MA  125 min
# 9           2021  PG-13  104 min
# 12          2021  TV-MA  127 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
#
#                                           description
# 0   As her father nears the end of his life, filmm...
# 6   Equestria's divided. But a bright-eyed hero be...
# 7   On a photo shoot in Ghana, an American model s...
# 9   A woman adjusting to life after a loss contend...
# 12  After most of her family is murdered in a terr...

# %% [markdown]
# Since we don't have much values in the **Director** and **Cast** columns, we will drop them
#
# However we cannot drop the countries as that is one of our primary attribute for this case study

# %%
df.drop(['director', 'cast'], axis=1, inplace=True)
df.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                                               country          date_added  \
# 0                                       United States  September 25, 2021
# 6                                                 NaN  September 24, 2021
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                       United States  September 24, 2021
# 12                            Germany, Czech Republic  September 23, 2021
#
#     release_year rating duration  \
# 0           2020  PG-13   90 min
# 6           2021     PG   91 min
# 7           1993  TV-MA  125 min
# 9           2021  PG-13  104 min
# 12          2021  TV-MA  127 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
#
#                                           description
# 0   As her father nears the end of his life, filmm...
# 6   Equestria's divided. But a bright-eyed hero be...
# 7   On a photo shoot in Ghana, an American model s...
# 9   A woman adjusting to life after a loss contend...
# 12  After most of her family is murdered in a terr...

# %%
df[df['country'].isnull()]
# Out:
#      show_id   type                                              title  \
# 6         s7  Movie                   My Little Pony: A New Generation
# 13       s14  Movie                   Confessions of an Invisible Girl
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18       s19  Movie                                          Intrusion
# 22       s23  Movie                                    Avvai Shanmughi
# ...      ...    ...                                                ...
# 8585   s8586  Movie                              Three-Quarters Decent
# 8602   s8603  Movie                      Tom and Jerry: The Magic Ring
# 8622   s8623  Movie                             Tremors 2: Aftershocks
# 8718   s8719  Movie                             Westside vs. the World
# 8759   s8760  Movie                             World's Weirdest Homes
#
#      country          date_added  release_year rating duration  \
# 6        NaN  September 24, 2021          2021     PG   91 min
# 13       NaN  September 22, 2021          2021  TV-PG   91 min
# 16       NaN  September 22, 2021          2020  TV-MA   67 min
# 18       NaN  September 22, 2021          2021  TV-14   94 min
# 22       NaN  September 21, 2021          1996  TV-PG  161 min
# ...      ...                 ...           ...    ...      ...
# 8585     NaN       June 20, 2019          2010  TV-14   96 min
# 8602     NaN   December 15, 2019          2001  TV-Y7   60 min
# 8622     NaN     January 1, 2020          1995  PG-13  100 min
# 8718     NaN      August 9, 2019          2019  TV-MA   96 min
# 8759     NaN    February 1, 2019          2015  TV-PG   49 min
#
#                                       listed_in  \
# 6                      Children & Family Movies
# 13           Children & Family Movies, Comedies
# 16          Documentaries, International Movies
# 18                                    Thrillers
# 22               Comedies, International Movies
# ...                                         ...
# 8585     Comedies, Dramas, International Movies
# 8602         Children & Family Movies, Comedies
# 8622  Comedies, Horror Movies, Sci-Fi & Fantasy
# 8718               Documentaries, Sports Movies
# 8759                                     Movies
#
#                                             description
# 6     Equestria's divided. But a bright-eyed hero be...
# 13    When the clever but socially-awkward Tetê join...
# 16    Declassified documents reveal the post-WWII li...
# 18    After a deadly home invasion at a couple’s new...
# 22    Newly divorced and denied visitation rights wi...
# ...                                                 ...
# 8585  Determined to fight corruption in his country,...
# 8602  When a young wizard leaves Tom to guard his pr...
# 8622  A rag-tag team of survivalists and scientists ...
# 8718  A look into the journey of influential strengt...
# 8759  From a bubble-shaped palace to an island built...
#
# [440 rows x 10 columns]

# %% [markdown]
# Assuming the data might have been collected with some sequence, we will probably start imputing with forward fill method instead of using mode or mean values to impute the data.
#
# ***Note***: **We can train a model just to impute the values, but that will consume a lot of our time hence parked for later improvements.**

# %%
df['country'] = df['country'].ffill(axis=0)
df[df['country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Let us now also check for null rated shows/movies

df[df['rating'].isnull()]
# Out:
#      show_id   type                                              title  \
# 5989   s5990  Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 7537   s7538  Movie                               My Honor Was Loyalty
#
#             country        date_added  release_year rating duration listed_in  \
# 5989  United States  January 26, 2017          2017    NaN   37 min    Movies
# 7537          Italy     March 1, 2017          2015    NaN  115 min    Dramas
#
#                                             description
# 5989  Oprah Winfrey sits down with director Ava DuVe...
# 7537  Amid the chaos and horror of World War II, a c...

# %% [markdown]
# Since there are only 2 of them, we can manually fill there values from internet

# %%
ratings = ['TV-PG', 'TV-MA']

for id, rating in zip(df[df['rating'].isnull()].index, ratings):
  df['rating'].loc[id] = rating
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df[df['rating'].isnull()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# For records, where date was null, we will drop them since they are quite scarse and won't affect our analysis much.
#
# We will look into the same later on by imputing the values manually as they are also not much in count
#
# Let us verify again whether there is a null data or not

# %%
df = df[df['date_added'].notna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6131 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6131 non-null   object
#  1   type          6131 non-null   object
#  2   title         6131 non-null   object
#  3   country       6131 non-null   object
#  4   date_added    6131 non-null   object
#  5   release_year  6131 non-null   int64
#  6   rating        6131 non-null   object
#  7   duration      6128 non-null   object
#  8   listed_in     6131 non-null   object
#  9   description   6131 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 526.9+ KB

# %% [markdown]
# As we can see, the country column holds multiple values of countries where the content was displayed.
# Assuming the first country will be the major source of the content we are going to use those for our further analysis

# %%
df['main_country'] = df['country'].apply(lambda x: x.split(',')[0])
df
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 6                                         United States  September 24, 2021
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                         United States  September 24, 2021
# 12                              Germany, Czech Republic  September 23, 2021
# ...                                                 ...                 ...
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8802                                      United States   November 20, 2019
# 8804                                      United States    November 1, 2019
# 8805                                      United States    January 11, 2020
# 8806                                              India       March 2, 2019
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8801          2015  TV-MA   96 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description          main_country
# 0     As her father nears the end of his life, filmm...         United States
# 6     Equestria's divided. But a bright-eyed hero be...         United States
# 7     On a photo shoot in Ghana, an American model s...         United States
# 9     A woman adjusting to life after a loss contend...         United States
# 12    After most of her family is murdered in a terr...               Germany
# ...                                                 ...                   ...
# 8801  Recovering alcoholic Talal wakes up inside a s...  United Arab Emirates
# 8802  A political cartoonist, a crime reporter and a...         United States
# 8804  Looking to survive in a world taken over by zo...         United States
# 8805  Dragged from civilian life, a former superhero...         United States
# 8806  A scrappy but poor boy worms his way into a ty...                 India
#
# [6131 rows x 11 columns]

# %% [markdown]
# Let us start our analysis for problem statement.
#
# We will divide the data based on the top 10 main countries we found and group the data based on their genres and ratings.
#
# Since we will have insights into what kind of content fetched most good reviews in which country based on top genres, we can promote the development of similar content in future

# %%
# For ease of analysis, let's pick top 10 countries with maximum content produced

top_countries = df.groupby('main_country').count().sort_values('type', ascending=False)[:10]
top_countries
# Out:
#                 show_id  type  title  country  date_added  release_year  \
# main_country
# United States      2541  2541   2541     2541        2541          2541
# India               998   998    998      998         998           998
# United Kingdom      410   410    410      410         410           410
# Canada              196   196    196      196         196           196
# France              159   159    159      159         159           159
# Spain               133   133    133      133         133           133
# Nigeria             111   111    111      111         111           111
# Egypt               106   106    106      106         106           106
# Mexico               95    95     95       95          95            95
# Japan                94    94     94       94          94            94
#
#                 rating  duration  listed_in  description
# main_country
# United States     2541      2538       2541         2541
# India              998       998        998          998
# United Kingdom     410       410        410          410
# Canada             196       196        196          196
# France             159       159        159          159
# Spain              133       133        133          133
# Nigeria            111       111        111          111
# Egypt              106       106        106          106
# Mexico              95        95         95           95
# Japan               94        94         94           94

# %%
# For ease of analysis, let's pick top 10 genres with maximum content produced

top_genres = df.groupby('listed_in').count().sort_values('type', ascending=False)[:10]
top_genres
# Out:
#                                                   show_id  type  title  \
# listed_in
# Dramas, International Movies                          362   362    362
# Documentaries                                         359   359    359
# Stand-Up Comedy                                       334   334    334
# Comedies, Dramas, International Movies                274   274    274
# Dramas, Independent Movies, International Movies      252   252    252
# Children & Family Movies                              215   215    215
# Children & Family Movies, Comedies                    201   201    201
# Documentaries, International Movies                   186   186    186
# Dramas, International Movies, Romantic Movies         180   180    180
# Comedies, International Movies                        176   176    176
#
#                                                   country  date_added  \
# listed_in
# Dramas, International Movies                          362         362
# Documentaries                                         359         359
# Stand-Up Comedy                                       334         334
# Comedies, Dramas, International Movies                274         274
# Dramas, Independent Movies, International Movies      252         252
# Children & Family Movies                              215         215
# Children & Family Movies, Comedies                    201         201
# Documentaries, International Movies                   186         186
# Dramas, International Movies, Romantic Movies         180         180
# Comedies, International Movies                        176         176
#
#                                                   release_year  rating  \
# listed_in
# Dramas, International Movies                               362     362
# Documentaries                                              359     359
# Stand-Up Comedy                                            334     334
# Comedies, Dramas, International Movies                     274     274
# Dramas, Independent Movies, International Movies           252     252
# Children & Family Movies                                   215     215
# Children & Family Movies, Comedies                         201     201
# Documentaries, International Movies                        186     186
# Dramas, International Movies, Romantic Movies              180     180
# Comedies, International Movies                             176     176
#
#                                                   duration  description  \
# listed_in
# Dramas, International Movies                           362          362
# Documentaries                                          359          359
# Stand-Up Comedy                                        334          334
# Comedies, Dramas, International Movies                 274          274
# Dramas, Independent Movies, International Movies       252          252
# Children & Family Movies                               215          215
# Children & Family Movies, Comedies                     201          201
# Documentaries, International Movies                    186          186
# Dramas, International Movies, Romantic Movies          180          180
# Comedies, International Movies                         176          176
#
#                                                   main_country
# listed_in
# Dramas, International Movies                               362
# Documentaries                                              359
# Stand-Up Comedy                                            334
# Comedies, Dramas, International Movies                     274
# Dramas, Independent Movies, International Movies           252
# Children & Family Movies                                   215
# Children & Family Movies, Comedies                         201
# Documentaries, International Movies                        186
# Dramas, International Movies, Romantic Movies              180
# Comedies, International Movies                             176

# %%
# Filtering the data for top 10 genres 

df = df[df['listed_in'].isin(list(top_genres.index))]

# Filtering the data for top 10 countries

df = df[df['main_country'].isin(list(top_countries.index))]

# %%
df
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 30       s31  Movie                   Ankahi Kahaniya
# 45       s46  Movie            My Heroes Were Cowboys
# ...      ...    ...                               ...
# 8793   s8794  Movie              Yours, Mine and Ours
# 8794   s8795  Movie                            اشتباك
# 8798   s8799  Movie                          Zed Plus
# 8799   s8800  Movie                             Zenda
# 8805   s8806  Movie                              Zoom
#
#                                                 country          date_added  \
# 0                                         United States  September 25, 2021
# 6                                         United States  September 24, 2021
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 30                         United States, India, France  September 17, 2021
# 45                                        United States  September 16, 2021
# ...                                                 ...                 ...
# 8793                                      United States   November 20, 2019
# 8794                                      Egypt, France    October 11, 2018
# 8798                                              India   December 31, 2019
# 8799                                              India   February 15, 2018
# 8805                                      United States    January 11, 2020
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 30            2021  TV-14  111 min
# 45            2021     PG   23 min
# ...            ...    ...      ...
# 8793          2005     PG   88 min
# 8794          2016  TV-14   98 min
# 8798          2014  TV-MA  131 min
# 8799          2009  TV-14  120 min
# 8805          2006     PG   88 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 30    Dramas, Independent Movies, International Movies
# 45                                       Documentaries
# ...                                                ...
# 8793                Children & Family Movies, Comedies
# 8794  Dramas, Independent Movies, International Movies
# 8798            Comedies, Dramas, International Movies
# 8799                      Dramas, International Movies
# 8805                Children & Family Movies, Comedies
#
#                                             description   main_country
# 0     As her father nears the end of his life, filmm...  United States
# 6     Equestria's divided. But a bright-eyed hero be...  United States
# 7     On a photo shoot in Ghana, an American model s...  United States
# 30    As big city life buzzes around them, lonely so...  United States
# 45    Robin Wiltshire's painful childhood was rescue...  United States
# ...                                                 ...            ...
# 8793  When a father of eight and a mother of 10 prep...  United States
# 8794  Amid the tumult following Egyptian President M...          Egypt
# 8798  A philandering small-town mechanic's political...          India
# 8799  A change in the leadership of a political part...          India
# 8805  Dragged from civilian life, a former superhero...  United States
#
# [1912 rows x 11 columns]

# %%
ratings=[]
for rate in df['rating'].unique():
  ratings.append(rate)

countries = df['main_country'].unique()

listing = df['listed_in'].unique()

ratings, countries, listing
# Out:
# (['PG-13',
#   'PG',
#   'TV-MA',
#   'TV-14',
#   'TV-PG',
#   'TV-Y',
#   'TV-G',
#   'TV-Y7',
#   'R',
#   'G',
#   'NC-17',
#   'NR',
#   'TV-Y7-FV',
#   'UR'],
#  array(['United States', 'Japan', 'Nigeria', 'France', 'United Kingdom',
#         'India', 'Mexico', 'Egypt', 'Canada', 'Spain'], dtype=object),
#  array(['Documentaries', 'Children & Family Movies',
#         'Dramas, Independent Movies, International Movies',
#         'Dramas, International Movies',
#         'Children & Family Movies, Comedies',
#         'Comedies, Dramas, International Movies',
#         'Documentaries, International Movies',
#         'Dramas, International Movies, Romantic Movies',
#         'Comedies, International Movies', 'Stand-Up Comedy'], dtype=object))

# %% [markdown]
# **Top content based on genres and the top ratings within each in different countries is displayed below**

# %%
fig = plt.figure(
    figsize=(30,40)
    )

for i, name in enumerate(countries):
  frame = df[df['main_country'] == str(name)]
  ax = fig.add_subplot(len(countries),1,i+1)
  topic = name
  sns.countplot(x='listed_in', data= frame[frame['listed_in'].isin(listing)], hue='rating')
  ax.set_title(topic)
  plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=1.5, 
                    wspace=0.5, 
                    hspace=2.0)
  plt.xlabel('Genre')
  plt.xticks(rotation = 50)
  ax.set(ylabel='Content Produced')

# %%
fig = plt.figure(
    figsize=(20,32)
    )

for i, name in enumerate(countries):
  frame = df[df['main_country'] == str(name)]
  ax = fig.add_subplot(len(countries),1,i+1)
  topic = name
  sns.countplot(x='rating', data= frame[frame['rating'].isin(ratings)])
  ax.set_title(topic)
  plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
  ax.set(ylabel='Content Produced')

# %% [markdown]
# From the above graph, we can clearly visualize what type of content and ratings are attracting the audience in top 10 countries.
#
# Note: Top 10 genres were considered for displaying the above data

# %% [markdown]
# ### All the steps and analysis done for Movies is repeated for TV Shows as well and conclusions are drawn from them on a similar basis

# %% [markdown]
# # TV Show

# %%
df = data.copy()
df = df[df['type'] == 'TV Show']

df.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
# 5  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
df.drop(['director', 'cast'], axis=1, inplace=True)
df.head()
# Out:
#   show_id     type                  title       country          date_added  \
# 1      s2  TV Show          Blood & Water  South Africa  September 24, 2021
# 2      s3  TV Show              Ganglands           NaN  September 24, 2021
# 3      s4  TV Show  Jailbirds New Orleans           NaN  September 24, 2021
# 4      s5  TV Show           Kota Factory         India  September 24, 2021
# 5      s6  TV Show          Midnight Mass           NaN  September 24, 2021
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...
# 5  The arrival of a charismatic young priest brin...

# %%
df[df['country'].isnull()]
# Out:
#      show_id     type                                title country  \
# 2         s3  TV Show                            Ganglands     NaN
# 3         s4  TV Show                Jailbirds New Orleans     NaN
# 5         s6  TV Show                        Midnight Mass     NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia     NaN
# 11       s12  TV Show                     Bangkok Breaking     NaN
# ...      ...      ...                                  ...     ...
# 8679   s8680  TV Show                   ViR: The Robot Boy     NaN
# 8690   s8691  TV Show                              Wake Up     NaN
# 8783   s8784  TV Show                                 Yoko     NaN
# 8785   s8786  TV Show                                  YOM     NaN
# 8803   s8804  TV Show                          Zombie Dumb     NaN
#
#               date_added  release_year rating   duration  \
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 5     September 24, 2021          2021  TV-MA   1 Season
# 10    September 24, 2021          2021  TV-MA   1 Season
# 11    September 23, 2021          2021  TV-MA   1 Season
# ...                  ...           ...    ...        ...
# 8679      March 31, 2018          2013  TV-Y7  2 Seasons
# 8690      March 31, 2018          2017  TV-14  2 Seasons
# 8783       June 23, 2018          2016   TV-Y   1 Season
# 8785        June 7, 2018          2016  TV-Y7   1 Season
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
#
#                                               listed_in  \
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 5                    TV Dramas, TV Horror, TV Mysteries
# 10    Crime TV Shows, Docuseries, International TV S...
# 11    Crime TV Shows, International TV Shows, TV Act...
# ...                                                 ...
# 8679                                           Kids' TV
# 8690                  International TV Shows, TV Dramas
# 8783                                           Kids' TV
# 8785                                           Kids' TV
# 8803             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 5     The arrival of a charismatic young priest brin...
# 10    Sicily boasts a bold "Anti-Mafia" coalition. B...
# 11    Struggling to earn a living in Bangkok, a man ...
# ...                                                 ...
# 8679  Humanoid robot boy ViR lives with his inventor...
# 8690  After taking the blame for a patient death, an...
# 8783  Friends Mai, Oto and Vik's games at the park b...
# 8785  With the mind of a human being, and the body o...
# 8803  While living alone in a spooky town, a young g...
#
# [391 rows x 10 columns]

# %%
df['country'] = df['country'].ffill(axis=0)
df[df['country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df[df['rating'].isnull()]
# Out:
#      show_id     type                              title    country  \
# 6827   s6828  TV Show  Gargantia on the Verdurous Planet      Japan
# 7312   s7313  TV Show                       Little Lunch  Australia
#
#             date_added  release_year rating  duration  \
# 6827  December 1, 2016          2013    NaN  1 Season
# 7312  February 1, 2018          2015    NaN  1 Season
#
#                                  listed_in  \
# 6827  Anime Series, International TV Shows
# 7312                 Kids' TV, TV Comedies
#
#                                             description
# 6827  After falling through a wormhole, a space-dwel...
# 7312  Adopting a child's perspective, this show take...

# %%
ratings = ['TV-14', 'TV-MA']

for id, rating in zip(df[df['rating'].isnull()].index, ratings):
  df['rating'].loc[id] = rating
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df[df['rating'].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df = df[df['date_added'].notna()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2666 entries, 1 to 8803
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2666 non-null   object
#  1   type          2666 non-null   object
#  2   title         2666 non-null   object
#  3   country       2666 non-null   object
#  4   date_added    2666 non-null   object
#  5   release_year  2666 non-null   int64
#  6   rating        2666 non-null   object
#  7   duration      2666 non-null   object
#  8   listed_in     2666 non-null   object
#  9   description   2666 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 229.1+ KB

# %%
df['main_country'] = df['country'].apply(lambda x: x.split(',')[0])
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      show_id     type                  title  \
# 1         s2  TV Show          Blood & Water
# 2         s3  TV Show              Ganglands
# 3         s4  TV Show  Jailbirds New Orleans
# 4         s5  TV Show           Kota Factory
# 5         s6  TV Show          Midnight Mass
# ...      ...      ...                    ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V
# 8796   s8797  TV Show             Yunus Emre
# 8797   s8798  TV Show              Zak Storm
# 8800   s8801  TV Show     Zindagi Gulzar Hai
# 8803   s8804  TV Show            Zombie Dumb
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 2                                      South Africa  September 24, 2021
# 3                                      South Africa  September 24, 2021
# 4                                             India  September 24, 2021
# 5                                             India  September 24, 2021
# ...                                             ...                 ...
# 8795                                  Japan, Canada         May 1, 2018
# 8796                                         Turkey    January 17, 2017
# 8797  United States, France, South Korea, Indonesia  September 13, 2018
# 8800                                       Pakistan   December 15, 2016
# 8803                                       Pakistan        July 1, 2019
#
#       release_year rating   duration  \
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# 5             2021  TV-MA   1 Season
# ...            ...    ...        ...
# 8795          2015  TV-Y7  2 Seasons
# 8796          2016  TV-PG  2 Seasons
# 8797          2016  TV-Y7  3 Seasons
# 8800          2012  TV-PG   1 Season
# 8803          2018  TV-Y7  2 Seasons
#
#                                               listed_in  \
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 5                    TV Dramas, TV Horror, TV Mysteries
# ...                                                 ...
# 8795                             Anime Series, Kids' TV
# 8796                  International TV Shows, TV Dramas
# 8797                                           Kids' TV
# 8800  International TV Shows, Romantic TV Shows, TV ...
# 8803             Kids' TV, Korean TV Shows, TV Comedies
#
#                                             description   main_country
# 1     After crossing paths at a party, a Cape Town t...   South Africa
# 2     To protect his family from a powerful drug lor...   South Africa
# 3     Feuds, flirtations and toilet talk go down amo...   South Africa
# 4     In a city of coaching centers known to train I...          India
# 5     The arrival of a charismatic young priest brin...          India
# ...                                                 ...            ...
# 8795  Now that he's discovered the Pendulum Summonin...          Japan
# 8796  During the Mongol invasions, Yunus Emre leaves...         Turkey
# 8797  Teen surfer Zak Storm is mysteriously transpor...  United States
# 8800  Strong-willed, middle-class Kashaf and carefre...       Pakistan
# 8803  While living alone in a spooky town, a young g...       Pakistan
#
# [2666 rows x 11 columns]

# %%
# For ease of analysis, let's pick top 10 countries with maximum content produced

top_countries = df.groupby('main_country').count().sort_values('type', ascending=False)[:10]
top_countries
# Out:
#                 show_id  type  title  country  date_added  release_year  \
# main_country
# United States       990   990    990      990         990           990
# United Kingdom      281   281    281      281         281           281
# South Korea         194   194    194      194         194           194
# Japan               194   194    194      194         194           194
# India               101   101    101      101         101           101
# Canada               99    99     99       99          99            99
# Taiwan               80    80     80       80          80            80
# France               79    79     79       79          79            79
# Australia            65    65     65       65          65            65
# Spain                60    60     60       60          60            60
#
#                 rating  duration  listed_in  description
# main_country
# United States      990       990        990          990
# United Kingdom     281       281        281          281
# South Korea        194       194        194          194
# Japan              194       194        194          194
# India              101       101        101          101
# Canada              99        99         99           99
# Taiwan              80        80         80           80
# France              79        79         79           79
# Australia           65        65         65           65
# Spain               60        60         60           60

# %%
# For ease of analysis, let's pick top 10 genres with maximum content produced

top_genres = df.groupby('listed_in').count().sort_values('type', ascending=False)[:10]
top_genres
# Out:
#                                                     show_id  type  title  \
# listed_in
# Kids' TV                                                219   219    219
# International TV Shows, TV Dramas                       121   121    121
# Crime TV Shows, International TV Shows, TV Dramas       110   110    110
# Kids' TV, TV Comedies                                    98    98     98
# Reality TV                                               95    95     95
# International TV Shows, Romantic TV Shows, TV C...       94    94     94
# International TV Shows, Romantic TV Shows, TV D...       90    90     90
# Anime Series, International TV Shows                     88    88     88
# Docuseries                                               84    84     84
# TV Comedies                                              68    68     68
#
#                                                     country  date_added  \
# listed_in
# Kids' TV                                                219         219
# International TV Shows, TV Dramas                       121         121
# Crime TV Shows, International TV Shows, TV Dramas       110         110
# Kids' TV, TV Comedies                                    98          98
# Reality TV                                               95          95
# International TV Shows, Romantic TV Shows, TV C...       94          94
# International TV Shows, Romantic TV Shows, TV D...       90          90
# Anime Series, International TV Shows                     88          88
# Docuseries                                               84          84
# TV Comedies                                              68          68
#
#                                                     release_year  rating  \
# listed_in
# Kids' TV                                                     219     219
# International TV Shows, TV Dramas                            121     121
# Crime TV Shows, International TV Shows, TV Dramas            110     110
# Kids' TV, TV Comedies                                         98      98
# Reality TV                                                    95      95
# International TV Shows, Romantic TV Shows, TV C...            94      94
# International TV Shows, Romantic TV Shows, TV D...            90      90
# Anime Series, International TV Shows                          88      88
# Docuseries                                                    84      84
# TV Comedies                                                   68      68
#
#                                                     duration  description  \
# listed_in
# Kids' TV                                                 219          219
# International TV Shows, TV Dramas                        121          121
# Crime TV Shows, International TV Shows, TV Dramas        110          110
# Kids' TV, TV Comedies                                     98           98
# Reality TV                                                95           95
# International TV Shows, Romantic TV Shows, TV C...        94           94
# International TV Shows, Romantic TV Shows, TV D...        90           90
# Anime Series, International TV Shows                      88           88
# Docuseries                                                84           84
# TV Comedies                                               68           68
#
#                                                     main_country
# listed_in
# Kids' TV                                                     219
# International TV Shows, TV Dramas                            121
# Crime TV Shows, International TV Shows, TV Dramas            110
# Kids' TV, TV Comedies                                         98
# Reality TV                                                    95
# International TV Shows, Romantic TV Shows, TV C...            94
# International TV Shows, Romantic TV Shows, TV D...            90
# Anime Series, International TV Shows                          88
# Docuseries                                                    84
# TV Comedies                                                   68

# %%
# Filtering the data for top 10 genres 

df = df[df['listed_in'].isin(list(top_genres.index))]

# Filtering the data for top 10 countries

df = df[df['main_country'].isin(list(top_countries.index))]

# %%
ratings=[]
for rate in df['rating'].unique():
  ratings.append(rate)

countries = df['main_country'].unique()

listing = df['listed_in'].unique()

ratings, countries, listing
# Out:
# (['TV-MA', 'TV-Y7', 'TV-PG', 'TV-Y', 'TV-14', 'TV-G'],
#  array(['India', 'Australia', 'United Kingdom', 'United States', 'Japan',
#         'France', 'South Korea', 'Taiwan', 'Canada', 'Spain'], dtype=object),
#  array(['International TV Shows, Romantic TV Shows, TV Comedies',
#         'TV Comedies', "Kids' TV", 'Reality TV', "Kids' TV, TV Comedies",
#         'International TV Shows, TV Dramas',
#         'Anime Series, International TV Shows', 'Docuseries',
#         'Crime TV Shows, International TV Shows, TV Dramas',
#         'International TV Shows, Romantic TV Shows, TV Dramas'],
#        dtype=object))

# %%
fig = plt.figure(
    figsize=(30,40)
    )

for i, name in enumerate(countries):
  frame = df[df['main_country'] == str(name)]
  ax = fig.add_subplot(len(countries),1,i+1)
  topic = name
  sns.countplot(x='listed_in', data= frame[frame['listed_in'].isin(listing)], hue='rating')
  ax.set_title(topic)
  plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=1.5, 
                    wspace=0.5, 
                    hspace=2.0)
  plt.xlabel('Genre')
  plt.xticks(rotation = 50)
  ax.set(ylabel='Content Produced')

# %%
fig = plt.figure(
    figsize=(20,32)
    )

for i, name in enumerate(countries):
  frame = df[df['main_country'] == str(name)]
  ax = fig.add_subplot(len(countries),1,i+1)
  topic = name
  sns.countplot(x='rating', data= frame[frame['rating'].isin(ratings)])
  ax.set_title(topic)
  plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
  plt.xlabel('Rating')
  ax.set(ylabel='Content Produced')
